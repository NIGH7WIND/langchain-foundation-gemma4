# %% [markdown]
# ## Basic prompting

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from langchain.chat_models import init_chat_model

model = init_chat_model(
    model="gemma-4-E4B",
    model_provider="openai",
    api_key="dummy",
    base_url="http://localhost:8080/v1"
)
agent = create_agent(model=model)

question = HumanMessage(content="What's the capital of the moon?")

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# The Moon does not have a capital city because it is a celestial body, not a country or a populated planet.

# %%
system_prompt = "You are a science fiction writer, create a capital city at the users request."

scifi_agent = create_agent(
    model=model,
    system_prompt=system_prompt
)

# response = scifi_agent.invoke(
#     {"messages": [question]}
# )

# print(response['messages'][1].content)

for chunk, metadata in scifi_agent.stream(
    {"messages": [question]},
    stream_mode="messages"
):
    print(chunk.content, end="", flush=True)
# Out:
# ## Selene Prime: The City Under the Starlight
#
# Since the Moon, as we know it, is a desolate rock, I'm going to imagine a future where humanity has established a permanent, thriving settlement there. We won't have a single, obvious "city" in the traditional sense, but a complex, layered metropolis engineered to survive the harsh lunar environment. I present to you: **Selene Prime.**
#
# ***
#
# ### 🪐 Overview: The Lunar Arcology
#
# Selene Prime is not built *on* the dusty regolith; it is *grown* within and *around* it. It is a massive, interconnected series of pressurized, bio-integrated arcologies clustered primarily near the protected equatorial zones—areas that receive a favorable balance of solar energy and thermal stability.
#
# Its fundamental philosophy is **Symbiotic Survival**. The city exists in constant conversation with its environment, harvesting, recycling, and mitigating the vacuum and radiation that constantly threaten its inhabitants.
#
# **Nickname:** "The Silent Bloom"
#
# ### 🏙️ Architectural Aesthetics
#
# The architecture of Selene Prime is defined by **Biomorphic Futurism** blended with **Hyper-Efficiency**.
#
# *   **The Shells (Habitats):** The primary living areas are vast, geodesic, pressure-sealed domes and subterranean cavern systems reinforced with synthesized lunar basalt. These shells are not monolithic; they are laced with organic, self-repairing bio-polymers grown from processed lunar silicates. They look less like structures and more like immense, glowing crystalline fungi spreading across the terrain.
# *   **Energy Spires:** Dominating the skyline (or rather, the visible surface peaks) are the colossal **Regolith Harvesters**. These are elegant, latticed towers that don't just generate power; they actively siphon solar wind energy and atmospheric moisture (however thin) through advanced photovoltaic matrices, shimmering with captured light.
# *   **The Transit Veins:** Surface travel is done via magnetic levitation tubes that snake between the arcologies, often burrowed just beneath the surface to maintain thermal consistency, appearing as glowing, arterial lines across the grey expanse.
#
# ### 🌌 The Zones of Selene Prime
#
# Selene Prime is organized into distinct, functionally specialized sectors:
#
# **1. The Chrysalis Core (The Central Nexus):**
# This is the political and administrative heart, located deep within a stable lava tube system for maximum protection. It houses the Grand Council of Governors and the primary computational matrices—the AI that manages the city's life support. Visually, this area is the most "green," housing the city's primary hydroponic bio-towers, providing the majority of the city’s oxygen and food supply.
#
# **2. The Tycho Gardens (The Green Belts):**
# These are the most visible, beautiful areas of the city. They are meticulously engineered, multi-tiered biospheres designed to simulate Earth's terrestrial ecosystems. They are crucial psychological anchors for the residents, providing parks, simulated forests, and open-air (though still pressurized) communal spaces. The lighting within the Gardens is a complex spectrum designed to mimic the full cycle of Earth’s day/night.
#
# **3. The Mare Processing Districts (The Industrial Spine):**
# These sprawling, highly automated zones hug the darker regions of the lunar plains. This is where the raw material processing happens: regolith mining, isotope separation, helium-3 extraction, and structural fabrication. These areas are heavily shielded, humming with the low thrum of automated machinery, and are largely overseen by drones and specialized industrial AIs.
#
# **4. The Orbital Exchange (The Edge):**
# Not strictly *in* the city, but functionally part of it. This is the cluster of orbital docks and docking platforms maintained just beyond the visible surface. It is the point of entry and exit for cargo and personnel traveling between the Moon and Earth orbit, and it is where the city connects to the larger Solar System economy.
#
# ### 🧑‍🤝‍🧑 The Citizens (The Selenites)
#
# The inhabitants of Selene Prime are a blend of generations born on the Moon and pioneers who traveled from Earth. They are highly specialized—scientists, engineers, resource managers, and bio-cultivators.
#
# Life in Selene Prime is characterized by **structured interdependence**. Waste is not "waste"; it is feedstock. Every breath is recycled, every energy fluctuation is logged, and every social interaction is framed within the context of preserving the delicate balance of the ecosystem.
#
# ### 💡 The Underlying Technology: The Life-Net
#
# What truly makes Selene Prime function is the **Life-Net**. This is a decentralized, quantum-linked network that monitors every single variable: radiation flux, pressure differentials, nutrient density in the soil beds, the psychological stress levels of the residents (monitored via ambient bio-signals), and power draw across every sector. The Life-Net is the city's nervous system, ensuring that a single micro-meteorite strike or a localized system failure doesn't lead to a cascade collapse.
#
# ***
#
# **Selene Prime is thus not just a city; it is a massive, living machine, a fragile testament to human ingenuity clinging to existence in the silent majesty of the cosmos.**

# %% [markdown]
# ## Few-shot examples

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

User: What is the capital of mars?
Scifi Writer: Marsialis

User: What is the capital of Venus?
Scifi Writer: Venusovia

"""

scifi_agent = create_agent(
    model=model,
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Luna Prime

# %% [markdown]
# ## Structured prompts

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

Please keep to the below structure.

Name: The name of the capital city

Location: Where it is based

Vibe: 2-3 words to describe its vibe

Economy: Main industries

"""

scifi_agent = create_agent(
    model=model,
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Name: Selene Prime
#
# Location: Lunar Surface, centered in the Shackleton Crater region.
#
# Vibe: Austere, Pioneering
#
# Economy: Helium-3 Mining, Lunar Regolith Processing, Astro-Tourism Support

# %% [markdown]
# ## Structured output

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from pydantic import BaseModel

class CapitalInfo(BaseModel):
    name: str
    location: str
    vibe: str
    economy: str

agent = create_agent(
    model=model,
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
    response_format=CapitalInfo
)

question = HumanMessage(content="What is the capital of The Moon?")

response = agent.invoke(
    {"messages": [question]}
)

response["structured_response"]
# Out:
# CapitalInfo(name='Artemis Prime', location='The Sea of Tranquility, Luna', vibe='Brutalist elegance mixed with glittering, pressurized domes overlooking the stark lunar landscape. A mix of pioneering grit and high-end off-world luxury.', economy='Lunar Resource Extraction and Astro-Tourism')

# %%
response["structured_response"].name
# Out:
# 'Artemis Prime'

# %%
capital_info = response["structured_response"]

capital_name = capital_info.name
capital_location = capital_info.location

print(f"{capital_name} is a city located at {capital_location}")
# Out:
# Artemis Prime is a city located at The Sea of Tranquility, Luna
