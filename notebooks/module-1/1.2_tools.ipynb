# %% [markdown]
# ## Tool definition

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.tools import tool

@tool
def square_root(x: float) -> float:
    """Calculate the square root of a number"""
    return x ** 0.5

# %%
@tool("square_root")
def tool1(x: float) -> float:
    """Calculate the square root of a number"""
    return x ** 0.5

# %%
@tool("square_root", description="Calculate the square root of a number")
def tool1(x: float) -> float:
    return x ** 0.5

# %%
tool1.invoke({"x": 467})
# Out:
# 21.61018278497431

# %% [markdown]
# ## Adding to agents

# %%
from langchain.agents import create_agent
from langchain.chat_models import init_chat_model

model = init_chat_model("gemma-4-E4b", model_provider="openai", api_key="dummy", base_url="http://localhost:8080/v1", temperature=0)

agent = create_agent(
    model=model,
    tools=[tool1],
    system_prompt="You are an arithmetic wizard. Use your tools to calculate the square root and square of any number."
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="What is the square root of 54321?")

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# The square root of 54321 is approximately 233.06865941177077.

# %%
from pprint import pprint

pprint(response['messages'])
# Out:
# [HumanMessage(content='What is the square root of 54321?', additional_kwargs={}, response_metadata={}, id='a454a60e-e8f7-47bc-b7cf-e7012e5529bd'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 17, 'prompt_tokens': 91, 'total_tokens': 108, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cache_write_tokens': None, 'cached_tokens': 69, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gemma-4-E4B-it-UD-Q4_K_XL.gguf', 'system_fingerprint': 'b9670-02810c7aa', 'id': 'chatcmpl-lCRX8vQ6yIwQCR0AeFc9xF8nFdmsEW5h', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--01a07f86-6b18-77e1-b102-77c477bb726c-0', tool_calls=[{'name': 'square_root', 'args': {'x': 54321}, 'id': 'CZ37HyAPCHdWHaKqjHqwMHfStVbBtGMs', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 91, 'output_tokens': 17, 'total_tokens': 108, 'input_token_details': {'cache_read': 69}, 'output_token_details': {}}),
#  ToolMessage(content='233.06865941177077', name='square_root', id='51627b97-7180-4c35-95ac-d429f5300c37', tool_call_id='CZ37HyAPCHdWHaKqjHqwMHfStVbBtGMs'),
#  AIMessage(content='The square root of 54321 is approximately 233.06865941177077.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 33, 'prompt_tokens': 138, 'total_tokens': 171, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cache_write_tokens': None, 'cached_tokens': 69, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gemma-4-E4B-it-UD-Q4_K_XL.gguf', 'system_fingerprint': 'b9670-02810c7aa', 'id': 'chatcmpl-FPzU7PnYycwOPbD1bAMD1AswcAevLUyH', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a07f86-7583-73c2-a365-554c5cf16a37-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 138, 'output_tokens': 33, 'total_tokens': 171, 'input_token_details': {'cache_read': 69}, 'output_token_details': {}})]

# %%
print(response["messages"][1].tool_calls)
# Out:
# [{'name': 'square_root', 'args': {'x': 54321}, 'id': 'CZ37HyAPCHdWHaKqjHqwMHfStVbBtGMs', 'type': 'tool_call'}]
