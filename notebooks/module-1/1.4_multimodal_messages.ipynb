# %% [markdown]
# ## Text input

# %% [markdown]
# https://platform.openai.com/docs/models

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent
from langchain.chat_models import init_chat_model

model = init_chat_model(
    model='gemma4',
    api_key='dummy',
    model_provider='openai',
    base_url='http://localhost:8080/v1'
)

agent = create_agent(
    model=model,
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content=[
    {"type": "text", "text": "What is the capital of The Moon?"}
])

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# ## Luna Prime: The City That Dreams of Earth
#
# The Moon, in the year 2347, is no longer a desolate rock. It is a jewel in the tapestry of human expansion, and its capital city is **Luna Prime**.
#
# Luna Prime isn't a sprawling metropolis of skyscrapers; it's a symphony of bio-integrated, pressurized domes and crystalline arcologies built into the scars and strengths of the lunar regolith. It is a city that breathes with the rhythm of the void.
#
# ---
#
# ### 🌌 Aesthetic and Architecture: The Crystalline Embrace
#
# The prevailing aesthetic of Luna Prime is **Biomimetic Futurism** crossed with **Harsh Industrial Elegance**.
#
# * **The Domes (The Biospheres):** The primary living areas are housed within massive, geodesic, energy-harvesting domes. These aren't mere glass bubbles; they are complex, self-regulating ecosystems. The outer layers are composed of **Chrono-Silicate**, a material that can self-repair minor micrometeorite damage and subtly shift its spectral reflectivity to manage internal temperature and radiation absorption.
# * **The Arcologies (The Core):** Nestled between the massive Biospheres are the administrative and technological hubs—the Arcologies. These towers are not built *up*, but *into* the crust. They are sculpted, multi-layered structures that burrow deep into the stabilized lava tubes, providing natural shielding from cosmic radiation. They often appear as elegant, segmented crystal formations, glowing softly with internal geothermal energy.
# * **The Surface Network:** The true infrastructure—the mining drills, the solar concentrators, the habitat nodes—is a sprawling, interconnected network of pressurized tunnels and reinforced trenches etched into the grey plains. These routes are often illuminated by low-frequency, bioluminescent algae cultivated in nutrient slurry channels.
#
# ### 🪐 Climate and Environment: Controlled Paradise
#
# The Moon is harsh, but Luna Prime is a carefully managed illusion of warmth.
#
# * **Atmosphere:** The city maintains a meticulously balanced, slightly enriched atmosphere (Nitrogen/Oxygen blend) within the primary habitats, filtered through massive, tiered lichen farms housed in the lower levels of the Biospheres. The air inside smells faintly of ozone and hydroponic herbs—a carefully engineered scent designed to mimic a pleasant terrestrial environment.
# * **Gravity Management:** Life within the city operates under **0.16G**, which is manageable but requires specialized infrastructure. Many public spaces utilize subtle magnetic levitation fields or slow-motion kinetic walkways to help residents adapt to the reduced pull.
# * **The Sky:** Outside the domes, the sky is an impossible, breathtaking expanse of absolute black velvet, punctuated by the impossibly sharp diamonds of distant stars. The view *into* the dome, where simulated, controlled blue-sky patterns are projected onto the upper ceiling panels, is considered the highest art form.
#
# ### 🏛️ Governance and Culture: The Equilibrium
#
# Luna Prime is ruled by the **Lunar Directorate**, a technocratic council comprised of the chief architects, energy specialists, and xenobiologists responsible for the city’s delicate balance with the hostile environment.
#
# * **The Ethos:** The cultural imperative of Luna Prime is **Conservation and Efficiency**. Waste is an almost philosophical sin. Every breath, every joule of power, every gram of regolith is accounted for.
# * **The Citizenry:** The populace is a highly specialized mix of deep-space miners, terraforming biologists, AI ethicists, and orbital engineers. They possess a unique blend of grounded stoicism (necessary for survival) and boundless, upward-looking ambition (driven by the promise of becoming a true off-world civilization).
# * **Daily Life:** Days are structured around energy cycles. The "Solar Bloom" (when maximum solar power is harvested) is the most vibrant time, characterized by public communal feasts utilizing synthesized or cultivated Moon-crops. Evenings are quiet, spent in the observation decks, gazing at the stunning, unblemished Earth hanging like a colossal, perfect blue marble in the black void.
#
# ### ⚡ Signature Feature: The Tycho Nexus
#
# The heart of Luna Prime is the **Tycho Nexus**. This is not a governmental building, but the city's power and consciousness core. It is located at the geographical center of the main complex, buried deep within a reinforced lava tube near the Tycho Crater. The Nexus houses the primary fusion reactor and the city's governing AI, *Sol Invictus*.
#
# When the city is in perfect operational harmony, the Nexus pulses with a soft, rhythmic internal light—the city's heartbeat. When a critical failure occurs, that light flickers, and the entire city feels the momentary, profound dread of the void pressing in.
#
# ---
#
# **In short, Luna Prime is a fragile, brilliantly illuminated bubble of human ingenuity, constantly wrestling with the infinite cold and vacuum surrounding it—a testament to human will written in crystalline light and pressurized air.**

# %% [markdown]
# ## Image input

# %%
from ipywidgets import FileUpload
from IPython.display import display

uploader = FileUpload(accept='.png', multiple=False)
display(uploader)
# Out:
# FileUpload(value=(), accept='.png', description='Upload')

# %%
print(uploader.value)
# Out:
# ({'name': 'Untitled design (1).png', 'type': 'image/png', 'size': 897004, 'content': <memory at 0x000002081BA07A00>, 'last_modified': datetime.datetime(2026, 9, 4, 16, 20, 34, 615000, tzinfo=datetime.timezone.utc)},)

# %%
import base64

# Get the first (and only) uploaded file dict
uploaded_file = uploader.value[0]

# This is a memoryview
content_mv = uploaded_file["content"]

# Convert memoryview -> bytes
img_bytes = bytes(content_mv)  # or content_mv.tobytes()

# Now base64 encode
img_b64 = base64.b64encode(img_bytes).decode("utf-8")

# %%
multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this capital"},
    {"type": "image", "base64": img_b64, "mime_type": "image/png"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
# Out:
# ## Lumina: The City of Shifting Light
#
# The image you provided—with its ethereal, looping lines of soft violet, its sense of fluid, controlled energy, and its almost biological organicism—inspires a capital city not of rigid steel and concrete, but of **structured luminescence and dynamic flow.**
#
# I present to you **Lumina**, the City of Shifting Light.
#
# ---
#
# ### 🏙️ Overview: The Flow State Metropolis
#
# Lumina is not built *on* the landscape; it is woven *into* it. It exists in a state of perpetual, controlled flux. The architectural philosophy of Lumina rejects hard angles in favor of elegant, parabolic, and serpentine curves—much like the energy patterns suggested in your image. The city appears less like a collection of buildings and more like a massive, intricate, living organism perpetually in motion, powered by the harnessing of ambient energy fields.
#
# **Location:** Lumina is situated in the vast, geologically stable plains of the former Equatorial Rift Zone, a region chosen not for its resources, but for its unique atmospheric energy conductivity.
#
# **Governing Principle:** **Harmonic Equilibrium.** The city runs on a principle of constant energetic balancing. Social structures, transit patterns, and even climate control are managed by a decentralized network of AI entities known as the 'Weavers,' ensuring that no single sector overdraws or stagnates.
#
# ### ✨ Architectural Signature: Bio-Luminescent Weaves
#
# The buildings in Lumina are not constructed from traditional materials. They are grown, or *spun*, from **Chrono-Silicate composites**—materials that react to and store photonic energy.
#
# *   **The Architecture:** Structures rise and flow like solidified ribbons of light. They have no discernible "facades"; instead, their surfaces are composed of millions of microscopic, light-sensitive crystalline filaments. At night, or during energy surges, the entire cityscape pulses with a deep, soft violet, shifting through gradients of indigo and pale azure—mirroring the aesthetic of your prompt.
# *   **The Transit System (The Current):** There are no roads. Transportation happens via the **Aether-Conduits**—vast, gently curved energy tubes woven between towers. Personal transport pods don't *drive*; they are *carried* along these magnetic-luminescent streams, moving with the grace of water flowing around stones.
# *   **The Verticality:** While the city is curved, it is intensely vertical. Towers often spiral upward, not in straight shafts, but in elegant, Mobius-strip-like forms, maximizing surface area for energy absorption.
#
# ### 💡 Societal Structure: The Cadence of the Citizen
#
# Life in Lumina is characterized by a deliberate pace—a rhythm dictated by the city’s energy cycles.
#
# *   **The Luminaries (Citizens):** Luminians are highly integrated into the city's energetic flow. They are specialists in complex systems maintenance, bio-engineering, energy harvesting, and aesthetic resonance. Status is not determined by wealth, but by one's ability to contribute a unique *harmonic frequency* to the city's overall operation.
# *   **The Nexus Centers:** These are the central, massive hubs—not governmental buildings, but massive, bio-synthetic power cores. These centers are where the city draws its lifeblood. Political decisions are often debated not in chambers, but within simulations run by the Weaver AI, modeling the societal impact of various energy allocations.
# *   **Culture:** Art in Lumina is kinetic. Performances involve light manipulation, bio-sculpting, and synchronized energy channeling. Silence is not emptiness; it is the pause between powerful energetic flows.
#
# ### 🌌 The Edge of Lumina: The Shimmering Expanse
#
# Beyond the glowing curves of the core city, the landscape transitions into the **Shimmering Expanse**. This is the periphery where the harvested ambient energy is dispersed. Here, massive, semi-sentient energy fields interact with the natural environment, creating breathtaking, ephemeral light shows—auroras that seem to drift across the horizon, perpetual energy storms contained just shy of chaos.
#
# **In essence, Lumina is the ultimate expression of elegance meeting infinite power. It is a city that breathes light, moves like water, and functions as a single, magnificent, energy-driven sculpture.**

# %% [markdown]
# ## Audio input

# %%
import sounddevice as sd
from scipy.io.wavfile import write
import base64
import io
import time
from tqdm import tqdm

# Recording settings
duration = 10  # seconds
sample_rate = 44100

print("Recording...")
audio = sd.rec(int(duration * sample_rate), samplerate=sample_rate, channels=1)
# Progress bar for the duration
for _ in tqdm(range(duration * 10)):   # update 10× per second
    time.sleep(0.1)
sd.wait()
print("Done.")

# Write WAV to an in-memory buffer
buf = io.BytesIO()
write(buf, sample_rate, audio)
wav_bytes = buf.getvalue()

aud_b64 = base64.b64encode(wav_bytes).decode("utf-8")
# Out:
# Recording...
# 100%|██████████| 100/100 [00:10<00:00,  9.84it/s]
# Done.

# %%
agent = create_agent(
    model=model,
)

multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this audio file"},
    {"type": "audio", "base64": aud_b64, "mime_type": "audio/wav"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
# Out:
# The audio indicates a discussion of the current economic situation in an unspecified economy. Specifically, it points to a division concerning GDP. However, the audio snippet is incomplete, leaving the full context of this division unclear.
